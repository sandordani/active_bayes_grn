# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import numpy as np
import matplotlib.pyplot as plt

# %%
conf_matrix = [[  13.55 , 193.45],
 [ 121.42 ,3767.58]]


conf_matrix = np.array(conf_matrix)

disp = ConfusionMatrixDisplay(confusion_matrix=conf_matrix, display_labels=[1,0])
disp.plot(cmap=plt.cm.Blues, values_format='10.2f')
plt.title('GFlow Net confusion matrix')
plt.show()

# %%
 conf_matrix = [[  15.05,  191.95], [ 129.02, 3759.98]]

conf_matrix = np.array(conf_matrix)

disp = ConfusionMatrixDisplay(confusion_matrix=conf_matrix, display_labels=[1,0])
disp.plot(cmap=plt.cm.Blues, values_format='10.2f')
plt.title('Bayes DAG confusion matrix')
plt.show()
